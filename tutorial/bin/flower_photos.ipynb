# %% [markdown]
# ## ResFPN Classifier Tutorial - Flower Photos

# %% [markdown]
# by *Ming Ming Zhang*

# %%
import tensorflow as tf
print('TF Version:', tf.__version__)
#print('GPUs:', len(tf.config.list_physical_devices('GPU')))

import numpy as np
import matplotlib.pyplot as plt
import os, sys
# Out:
# TF Version: 2.3.1

# %%
# python files directory
PY_DIR = #'directory/to/python/files'
sys.path.append(PY_DIR)

import resnet_fpn

# %% [markdown]
# ## Data Info

# %%
# dataset directory
DATASET_DIR = #'directory/to/covidx'

# %%
TRAIN_NUM_IMGS = {}

print('-----Training Set Info-----')
for class_name in os.listdir(DATASET_DIR):
    if class_name == 'LICENSE.txt':
        continue
    imgs_list = os.listdir(os.path.join(DATASET_DIR, class_name))
    num_imgs = len(imgs_list)
    TRAIN_NUM_IMGS[class_name] = num_imgs
    print('%s: %d images' % (class_name, num_imgs))
# Out:
# -----Training Set Info-----
# daisy: 633 images
# dandelion: 898 images
# roses: 641 images
# sunflowers: 699 images
# tulips: 799 images

# %% [markdown]
# ### TF Dataset

# %%
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=DATASET_DIR, 
    labels='inferred', 
    label_mode='int',
    class_names=None, 
    color_mode='rgb', 
    batch_size=BATCH_SIZE, 
    image_size=IMAGE_SIZE, 
    shuffle=True, 
    seed=123, 
    validation_split=0.1, 
    subset='training'
)

for x_train_batch, y_train_batch in train_ds.take(1):
    print(x_train_batch.shape, y_train_batch.shape)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 3303 files for training.
# (32, 256, 256, 3) (32,)

# %%
CLASS_NAMES = train_ds.class_names
print('classes:', CLASS_NAMES)
NUM_CLASSES = len(CLASS_NAMES)
# Out:
# classes: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=DATASET_DIR, 
    labels='inferred', 
    label_mode='int',
    class_names=None, 
    color_mode='rgb', 
    batch_size=BATCH_SIZE, 
    image_size=IMAGE_SIZE, 
    shuffle=True, 
    seed=123, 
    validation_split=0.1, 
    subset='validation'
)

for x_val_batch, y_val_batch in val_ds.take(1):
    print(x_val_batch.shape, y_val_batch.shape)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 367 files for validation.
# (32, 256, 256, 3) (32,)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(1)
val_ds = val_ds.cache().prefetch(1)

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(10, 10))
for x_train_batch, y_train_batch in train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(tf.cast(x_train_batch[i], tf.int32))
        plt.title(CLASS_NAMES[y_train_batch[i]])
        plt.axis('off')

# %% [markdown]
# ### ResFPN Classifiers

# %% [markdown]
# #### Without Pretrained ResNet Weights

# %%
ResFPN = resnet_fpn.ResFPN_Classifier(
    image_shape=IMAGE_SIZE + (3,), 
    num_classes=NUM_CLASSES, 
    num_filters=256, 
    architecture='resnet50', 
    augmentation=True,
    checkpoint_path=None,
    resnet_weights_path=None)

# %%
ResFPN.train(
    train_dataset=train_ds, 
    val_dataset=val_ds, 
    params={'lr':0.001, 'l2':0.3, 'epochs':5}, 
    loss_type='ce',
    save_weights=False)
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000
# 12/12 [==============================] - 1s 92ms/step - loss: 20.7059 - dense_resnet_loss: 0.9086 - dense_fpn_2_loss: 0.9809 - dense_fpn_3_loss: 0.9802 - dense_fpn_4_loss: 0.9678 - dense_fpn_5_loss: 0.9188 - dense_resnet_accuracy: 0.6594 - dense_fpn_2_accuracy: 0.6294 - dense_fpn_3_accuracy: 0.6349 - dense_fpn_4_accuracy: 0.6213 - dense_fpn_5_accuracy: 0.6567
#
# Top classifiers: ['resnet', 'res_fpn_5', 'res_fpn_4']
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002746A7998B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002746A7998B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# Validation accuracy: 0.6538194444444444

# %%
ensemble_class_ids, metrics, f1_score = ResFPN.predict(
    val_ds, CLASS_NAMES, display_metrics=True, top_idxes=top_idxes)
# Out:
# Test accuracy: 0.65
#
# daisy:
#   precision 0.62, recall 0.33, F1-score 0.42
# dandelion:
#   precision 0.70, recall 0.38, F1-score 0.48
# roses:
#   precision 0.51, recall 0.28, F1-score 0.34
# sunflowers:
#   precision 0.81, recall 0.36, F1-score 0.49
# tulips:
#   precision 0.63, recall 0.32, F1-score 0.42
#
# Average:
#   precision 0.65, recall 0.33, F1-score 0.43

# %% [markdown]
# #### With Pretrained ResNet Weights

# %%
filepath = #'path\to\pretrained_resnet_weights.h5'

# %%
pretrain_ResFPN = resnet_fpn.ResFPN_Classifier(
    image_shape=IMAGE_SIZE + (3,), 
    num_classes=NUM_CLASSES, 
    num_filters=256, 
    architecture='resnet50', 
    augmentation=True,
    checkpoint_path=None,
    resnet_weights_path=filepath)

# %%
pretrain_ResFPN.train(
    train_dataset=train_ds, 
    val_dataset=val_ds, 
    params={'lr':0.001, 'l2':0.3, 'epochs':5}, 
    loss_type='ce',
    save_weights=False)
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000274652BFAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000274652BFAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#   2/104 [..............................] - ETA: 28s - loss: 43.5431 - dense_resnet_loss: 1.8832 - dense_fpn_2_loss: 3.0985 - dense_fpn_3_loss: 2.2789 - dense_fpn_4_loss: 2.9199 - dense_fpn_5_loss: 2.0530 - dense_resnet_accuracy: 0.1562 - dense_fpn_2_accuracy: 0.1094 - dense_fpn_3_accuracy: 0.1875 - dense_fpn_4_accuracy: 0.2188 - dense_fpn_5_accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1240s vs `on_train_batch_end` time: 0.2120s). Check your callbacks.
# 104/104 [==============================] - ETA: 0s - loss: 34.5103 - dense_resnet_loss: 0.5941 - dense_fpn_2_loss: 0.7492 - dense_fpn_3_loss: 0.6582 - dense_fpn_4_loss: 0.6420 - dense_fpn_5_loss: 0.5571 - dense_resnet_accuracy: 0.7748 - dense_fpn_2_accuracy: 0.7496 - dense_fpn_3_accuracy: 0.7735 - dense_fpn_4_accuracy: 0.7760 - dense_fpn_5_accuracy: 0.7893WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002746A798168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002746A798168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# 104/104 [==============================] - 36s 346ms/step - loss: 31.7227 - dense_resnet_loss: 0.0786 - dense_fpn_2_loss: 0.1019 - dense_fpn_3_loss: 0.0914 - dense_fpn_4_loss: 0.0788 - dense_fpn_5_loss: 0.0624 - dense_resnet_accuracy: 0.9782 - dense_fpn_2_accuracy: 0.9661 - dense_fpn_3_accuracy: 0.9694 - dense_fpn_4_accuracy: 0.9740 - dense_fpn_5_accuracy: 0.9803 - val_loss: 32.3922 - val_dense_resnet_loss: 0.1632 - val_dense_fpn_2_loss: 0.2714 - val_dense_fpn_3_loss: 0.2448 - val_dense_fpn_4_loss: 0.1946 - val_dense_fpn_5_loss: 0.2085 - val_dense_resnet_accuracy: 0.9428 - val_dense_fpn_2_accuracy: 0.9319 - val_dense_fpn_3_accuracy: 0.9373 - val_dense_fpn_4_accuracy: 0.9373 - val_dense_fpn_5_accuracy: 0.9292
# Epoch 5/5
# 104/104 [==============================] - 36s 347ms/step - loss: 31.5553 - dense_resnet_loss: 0.0539 - dense_fpn_2_loss: 0.0563 - dense_fpn_3_loss: 0.0532 - dense_fpn_4_loss: 0.0437 - dense_fpn_5_loss: 0.0386 - dense_resnet_accuracy: 0.9864 - dense_fpn_2_accuracy: 0.9806 - dense_fpn_3_accuracy: 0.9830 - dense_fpn_4_accuracy: 0.9876 - dense_fpn_5_accuracy: 0.9894 - val_loss: 32.3006 - val_dense_resnet_loss: 0.1455 - val_dense_fpn_2_loss: 0.2313 - val_dense_fpn_3_loss: 0.2294 - val_dense_fpn_4_loss: 0.1913 - val_dense_fpn_5_loss: 0.1935 - val_dense_resnet_accuracy: 0.9401 - val_dense_fpn_2_accuracy: 0.9319 - val_dense_fpn_3_accuracy: 0.9264 - val_dense_fpn_4_accuracy: 0.9455 - val_dense_fpn_5_accuracy: 0.9482

# %%
pretrain_ResFPN.plot()

# %%
top_idxes, val_acc = pretrain_ResFPN.select_top(val_ds, top=3)
# Out:
# 12/12 [==============================] - 1s 98ms/step - loss: 32.3006 - dense_resnet_loss: 0.1455 - dense_fpn_2_loss: 0.2313 - dense_fpn_3_loss: 0.2294 - dense_fpn_4_loss: 0.1913 - dense_fpn_5_loss: 0.1935 - dense_resnet_accuracy: 0.9401 - dense_fpn_2_accuracy: 0.9319 - dense_fpn_3_accuracy: 0.9264 - dense_fpn_4_accuracy: 0.9455 - dense_fpn_5_accuracy: 0.9482
#
# Top classifiers: ['resnet', 'res_fpn_4', 'res_fpn_5']
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002746A78F0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002746A78F0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# Validation accuracy: 0.9505208333333334

# %%
ensemble_class_ids, metrics, f1_score = pretrain_ResFPN.predict(
    val_ds, CLASS_NAMES, display_metrics=True, top_idxes=top_idxes)
# Out:
# Test accuracy: 0.95
#
# daisy:
#   precision 0.98, recall 0.80, F1-score 0.88
# dandelion:
#   precision 0.99, recall 0.84, F1-score 0.91
# roses:
#   precision 0.87, recall 0.82, F1-score 0.84
# sunflowers:
#   precision 0.99, recall 0.82, F1-score 0.89
# tulips:
#   precision 0.89, recall 0.89, F1-score 0.88
#
# Average:
#   precision 0.95, recall 0.84, F1-score 0.88
